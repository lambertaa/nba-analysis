# %%
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta
import requests
import pickle
import os
import sys
sys.path.append(os.path.abspath("..")) 

from helpers import tankathon_bballgm_team_mapper
from data_retrieval.realgm_retr import get_realgm_allstar_rosters, get_realgm_allstar_roster

# %%
# constants
NYEARS = 5
DRAFT_HISTORY_ADJUSTMENTS_NYEARS = 5
ALL_STAR_ADJUSTMENT_NYEARS = 3

# %% [markdown]
# # Lottery Luck Adjustment

# %%
def get_draft_lottery_history(year_start, year_end, store_data: bool =True) -> dict[str, pd.DataFrame]:
    draft_lottery_results = {}
    years = list(range(year_start, year_end + 1))
    for year in years:

        # Extract the table for the current year
        url_format = "https://basketball.realgm.com/nba/draft/lottery_results/{year}"
        url = url_format.format(year=year)
        res = requests.get(url)
        soup = BeautifulSoup(res.text, 'html.parser')
        table = soup.find("table", class_="table-striped")

        if not table:
            print(f"No table found for year {year}")
            continue

        # convert the table to a DataFrame
        headers = [th.text.strip() for th in table.find_all("th")]
        rows = []
        for tr in table.find_all("tr")[1:]:  # Skip header
            row = [td.text.strip() for td in tr.find_all("td")]
            if row:
                rows.append(row)
        df = pd.DataFrame(rows, columns=headers)

        # Convert the "Pick Change" column to integers
        df["Pick Change"] = df["Pick Change"].str.replace("+", "", regex=False).astype(int)

        draft_lottery_results[year] = df

    if store_data:
        for year, df in draft_lottery_results.items():
            if not os.path.exists(f"data/draft_lottery_results_{year}.csv"):
                df.to_csv(f"data/draft_lottery_results_{year}.csv", index=False)
        # Save the results to a pickle file
        if not os.path.exists(f"data/draft_lottery_results_{year_start}_{year_end}.pkl"):
            with open(f"data/draft_lottery_results_{year_start}_{year_end}.pkl", "wb") as f:
                pickle.dump(draft_lottery_results, f)

    return draft_lottery_results

# %%
# collect draft lottery history data
max_year = datetime.now().year
min_year = max_year - DRAFT_HISTORY_ADJUSTMENTS_NYEARS
draft_lottery_history = get_draft_lottery_history(min_year, max_year - 1, store_data=True)

# %%
def get_current_lottery_odds() -> pd.DataFrame:

    url = 'https://www.tankathon.com/'
    res = requests.get(url)
    soup = BeautifulSoup(res.text, 'html.parser')
    table = soup.find("table", class_="draft-board")

    # convert the table to a DataFrame
    header_row = soup.find("tr", class_="headers")
    headers = [
        td.text.strip()
        for td in header_row.find_all("td")
        if 'mobile' not in td.get('class', [])
        and td.text.strip()  # Ignore empty cells
    ]
    rows = []
    for tr in table.find_all("tr", class_="pick-row-lottery"):
        tds = tr.find_all("td")
        row = []

        for i, td in enumerate(tds):
            # Special handling for team name column
            if "name" in td.get("class", []):
                desktop_team = td.find("div", class_="desktop")
                team_name = desktop_team.text.strip() if desktop_team else ""
                row.append(team_name)
            else:
                row.append(td.text.strip())

        if row:
            rows.append(row)
    return pd.DataFrame(rows, columns=headers)

# %%
# Load the current lottery odds
df_current = get_current_lottery_odds()
df_current['Team'] = df_current.Team.apply(lambda x: tankathon_bballgm_team_mapper[x])
df_current
# Out:
#    Pick                    Team Record  Win%    GB  Streak  L10  Top 4 #1 Ovr
# 0   110        Dallas Mavericks  39-43  .476  22.0  Lost 1  4-6   8.5%   1.8%
# 1    26       San Antonio Spurs  34-48  .415  17.0   Won 1  3-7  26.3%   6.0%
# 2    32      Philadelphia 76ers  24-58  .293   7.0  Lost 2  1-9  42.1%  10.5%
# 3    41       Charlotte Hornets  19-63  .232   2.0  Lost 7  1-9  52.1%  14.0%
# 4    54               Utah Jazz  17-65  .207    --  Lost 2  1-9  52.1%  14.0%
# 5    64      Washington Wizards  18-64  .220   1.0   Won 1  2-8  52.1%  14.0%
# 6    73    New Orleans Pelicans  21-61  .256   4.0  Lost 7  2-8  48.1%  12.5%
# 7    82           Brooklyn Nets  26-56  .317   9.0  Lost 3  3-7  37.2%   9.0%
# 8    92         Toronto Raptors  30-52  .366  13.0  Lost 2  5-5  31.9%   7.5%
# 9   101            Phoenix Suns  36-46  .439  19.0  Lost 1  1-9  17.3%   3.8%
# 10  111  Portland Trail Blazers  36-46  .439  19.0   Won 1  4-6  16.9%   3.7%
# 11   12           Chicago Bulls  39-43  .476  22.0   Won 3  7-3   8.0%   1.7%
# 12   13        Sacramento Kings  40-42  .488  23.0   Won 1  5-5   3.8%   0.8%
# 13   14           Atlanta Hawks  40-42  .488  23.0   Won 3  5-5   3.4%   0.7%

# %%
# join lottery team previous lottery results
df_joined = df_current.copy()
for year in draft_lottery_history:
    pick_change_series = draft_lottery_history[year][["Team", "Pick Change"]].copy()
    pick_change_series.rename(columns={"Pick Change": f"Pick Change_{year}"}, inplace=True)
    df_joined = df_joined.join(pick_change_series.set_index("Team"), on="Team")
df_joined
# Out:
#    Pick                    Team Record  Win%    GB  Streak  L10  Top 4 #1 Ovr  \
# 0   110        Dallas Mavericks  39-43  .476  22.0  Lost 1  4-6   8.5%   1.8%
# 1    26       San Antonio Spurs  34-48  .415  17.0   Won 1  3-7  26.3%   6.0%
# 2    32      Philadelphia 76ers  24-58  .293   7.0  Lost 2  1-9  42.1%  10.5%
# 3    41       Charlotte Hornets  19-63  .232   2.0  Lost 7  1-9  52.1%  14.0%
# 4    54               Utah Jazz  17-65  .207    --  Lost 2  1-9  52.1%  14.0%
# 5    64      Washington Wizards  18-64  .220   1.0   Won 1  2-8  52.1%  14.0%
# 6    73    New Orleans Pelicans  21-61  .256   4.0  Lost 7  2-8  48.1%  12.5%
# 7    82           Brooklyn Nets  26-56  .317   9.0  Lost 3  3-7  37.2%   9.0%
# 8    92         Toronto Raptors  30-52  .366  13.0  Lost 2  5-5  31.9%   7.5%
# 9   101            Phoenix Suns  36-46  .439  19.0  Lost 1  1-9  17.3%   3.8%
# 10  111  Portland Trail Blazers  36-46  .439  19.0   Won 1  4-6  16.9%   3.7%
# 11   12           Chicago Bulls  39-43  .476  22.0   Won 3  7-3   8.0%   1.7%
# 12   13        Sacramento Kings  40-42  .488  23.0   Won 1  5-5   3.8%   0.8%
# 13   14           Atlanta Hawks  40-42  .488  23.0   Won 3  5-5   3.4%   0.7%
#
#     Pick Change_2020  Pick Change_2021  Pick Change_2022  Pick Change_2023  \
# 0                NaN               NaN               NaN               0.0
# 1                0.0               0.0               0.0               2.0
# 2                NaN               NaN               NaN               NaN
# 3                5.0               0.0               0.0               2.0
# 4                NaN               NaN               NaN               0.0
# 5                0.0               NaN               0.0               0.0
# 6                0.0               0.0               NaN               0.0
# 7                NaN               NaN               NaN               NaN
# 8                NaN               3.0               NaN               0.0
# 9                0.0               NaN               NaN               NaN
# 10               NaN               NaN              -1.0               2.0
# 11               3.0               0.0               NaN               0.0
# 12               0.0               0.0               3.0               NaN
# 13              -2.0               NaN               NaN               NaN
#
#     Pick Change_2024
# 0                NaN
# 1                1.0
# 2                NaN
# 3               -3.0
# 4               -2.0
# 5                0.0
# 6                NaN
# 7                6.0
# 8               -2.0
# 9                NaN
# 10              -3.0
# 11               0.0
# 12               0.0
# 13               9.0

# %%
def convert_odds_to_balls(df: pd.DataFrame) -> pd.DataFrame:
    # Convert the odds to integers
    df['start_balls'] = df['#1 Ovr'].replace({'%': ''}, regex=True).astype(float) * 10
    return df
df_joined = convert_odds_to_balls(df_joined)
df_joined
# Out:
#    Pick                    Team Record  Win%    GB  Streak  L10  Top 4 #1 Ovr  \
# 0   110        Dallas Mavericks  39-43  .476  22.0  Lost 1  4-6   8.5%   1.8%
# 1    26       San Antonio Spurs  34-48  .415  17.0   Won 1  3-7  26.3%   6.0%
# 2    32      Philadelphia 76ers  24-58  .293   7.0  Lost 2  1-9  42.1%  10.5%
# 3    41       Charlotte Hornets  19-63  .232   2.0  Lost 7  1-9  52.1%  14.0%
# 4    54               Utah Jazz  17-65  .207    --  Lost 2  1-9  52.1%  14.0%
# 5    64      Washington Wizards  18-64  .220   1.0   Won 1  2-8  52.1%  14.0%
# 6    73    New Orleans Pelicans  21-61  .256   4.0  Lost 7  2-8  48.1%  12.5%
# 7    82           Brooklyn Nets  26-56  .317   9.0  Lost 3  3-7  37.2%   9.0%
# 8    92         Toronto Raptors  30-52  .366  13.0  Lost 2  5-5  31.9%   7.5%
# 9   101            Phoenix Suns  36-46  .439  19.0  Lost 1  1-9  17.3%   3.8%
# 10  111  Portland Trail Blazers  36-46  .439  19.0   Won 1  4-6  16.9%   3.7%
# 11   12           Chicago Bulls  39-43  .476  22.0   Won 3  7-3   8.0%   1.7%
# 12   13        Sacramento Kings  40-42  .488  23.0   Won 1  5-5   3.8%   0.8%
# 13   14           Atlanta Hawks  40-42  .488  23.0   Won 3  5-5   3.4%   0.7%
#
#     Pick Change_2020  Pick Change_2021  Pick Change_2022  Pick Change_2023  \
# 0                NaN               NaN               NaN               0.0
# 1                0.0               0.0               0.0               2.0
# 2                NaN               NaN               NaN               NaN
# 3                5.0               0.0               0.0               2.0
# 4                NaN               NaN               NaN               0.0
# 5                0.0               NaN               0.0               0.0
# 6                0.0               0.0               NaN               0.0
# 7                NaN               NaN               NaN               NaN
# 8                NaN               3.0               NaN               0.0
# 9                0.0               NaN               NaN               NaN
# 10               NaN               NaN              -1.0               2.0
# 11               3.0               0.0               NaN               0.0
# 12               0.0               0.0               3.0               NaN
# 13              -2.0               NaN               NaN               NaN
#
#     Pick Change_2024  start_balls
# 0                NaN         18.0
# 1                1.0         60.0
# 2                NaN        105.0
# 3               -3.0        140.0
# 4               -2.0        140.0
# 5                0.0        140.0
# 6                NaN        125.0
# 7                6.0         90.0
# 8               -2.0         75.0
# 9                NaN         38.0
# 10              -3.0         37.0
# 11               0.0         17.0
# 12               0.0          8.0
# 13               9.0          7.0

# %%
# lottery luck adjustment
def adjust_lottery_luck(df: pd.DataFrame) -> pd.DataFrame:
    # Adjust the lottery luck based on the previous year's pick change
    df['balls_lottery_luck_adjusted'] = df['start_balls'].copy()
    pick_change_cols = [col for col in df.columns if 'Pick Change_' in col]
    for pick_change_col in pick_change_cols:
        year = pick_change_col.split('_')[-1]
        normalizer = datetime.now().year - int(year)
        df['balls_lottery_luck_adjusted'] -= (df[pick_change_col].fillna(0).astype(int)*10) / normalizer
    return df
df_adjusted = adjust_lottery_luck(df_joined.copy())
df_adjusted['#1 Ovr Adjusted'] = (df_adjusted['balls_lottery_luck_adjusted'] / df_adjusted['balls_lottery_luck_adjusted'].sum() * 100).round(2).astype(str) + '%'
df_adjusted.sort_values(by='balls_lottery_luck_adjusted', ascending=False, inplace=True)
df_adjusted
# Out:
#    Pick                    Team Record  Win%    GB  Streak  L10  Top 4 #1 Ovr  \
# 4    54               Utah Jazz  17-65  .207    --  Lost 2  1-9  52.1%  14.0%
# 3    41       Charlotte Hornets  19-63  .232   2.0  Lost 7  1-9  52.1%  14.0%
# 5    64      Washington Wizards  18-64  .220   1.0   Won 1  2-8  52.1%  14.0%
# 6    73    New Orleans Pelicans  21-61  .256   4.0  Lost 7  2-8  48.1%  12.5%
# 2    32      Philadelphia 76ers  24-58  .293   7.0  Lost 2  1-9  42.1%  10.5%
# 8    92         Toronto Raptors  30-52  .366  13.0  Lost 2  5-5  31.9%   7.5%
# 10  111  Portland Trail Blazers  36-46  .439  19.0   Won 1  4-6  16.9%   3.7%
# 1    26       San Antonio Spurs  34-48  .415  17.0   Won 1  3-7  26.3%   6.0%
# 9   101            Phoenix Suns  36-46  .439  19.0  Lost 1  1-9  17.3%   3.8%
# 7    82           Brooklyn Nets  26-56  .317   9.0  Lost 3  3-7  37.2%   9.0%
# 0   110        Dallas Mavericks  39-43  .476  22.0  Lost 1  4-6   8.5%   1.8%
# 11   12           Chicago Bulls  39-43  .476  22.0   Won 3  7-3   8.0%   1.7%
# 12   13        Sacramento Kings  40-42  .488  23.0   Won 1  5-5   3.8%   0.8%
# 13   14           Atlanta Hawks  40-42  .488  23.0   Won 3  5-5   3.4%   0.7%
#
#     Pick Change_2020  Pick Change_2021  Pick Change_2022  Pick Change_2023  \
# 4                NaN               NaN               NaN               0.0
# 3                5.0               0.0               0.0               2.0
# 5                0.0               NaN               0.0               0.0
# 6                0.0               0.0               NaN               0.0
# 2                NaN               NaN               NaN               NaN
# 8                NaN               3.0               NaN               0.0
# 10               NaN               NaN              -1.0               2.0
# 1                0.0               0.0               0.0               2.0
# 9                0.0               NaN               NaN               NaN
# 7                NaN               NaN               NaN               NaN
# 0                NaN               NaN               NaN               0.0
# 11               3.0               0.0               NaN               0.0
# 12               0.0               0.0               3.0               NaN
# 13              -2.0               NaN               NaN               NaN
#
#     Pick Change_2024  start_balls  balls_lottery_luck_adjusted #1 Ovr Adjusted
# 4               -2.0        140.0                   160.000000           18.1%
# 3               -3.0        140.0                   150.000000          16.97%
# 5                0.0        140.0                   140.000000          15.84%
# 6                NaN        125.0                   125.000000          14.14%
# 2                NaN        105.0                   105.000000          11.88%
# 8               -2.0         75.0                    87.500000            9.9%
# 10              -3.0         37.0                    60.333333           6.83%
# 1                1.0         60.0                    40.000000           4.53%
# 9                NaN         38.0                    38.000000            4.3%
# 7                6.0         90.0                    30.000000           3.39%
# 0                NaN         18.0                    18.000000           2.04%
# 11               0.0         17.0                    11.000000           1.24%
# 12               0.0          8.0                    -2.000000          -0.23%
# 13               9.0          7.0                   -79.000000          -8.94%

# %% [markdown]
# # All Star Rest Penalty Adjustment

# %%
max_year = datetime.now().year
min_year = max_year - ALL_STAR_ADJUSTMENT_NYEARS
years = list(range(min_year, max_year))
as_df = get_realgm_allstar_rosters(years)
as_players = as_df.Player.values.tolist()

# %%
from data_retrieval.games_list_requester import GamesListRequester

Requester = GamesListRequester()
Requester.get_games_list(season_id=f'{max_year-1}-{str(max_year)[-2:]}', season_type='Regular Season')
games_df = Requester.df.copy()

# add team id to df_adjusted
if 'Team_Id' not in df_adjusted.columns:
    df_adjusted = df_adjusted.merge(games_df[['TEAM_NAME','TEAM_ID']].drop_duplicates(subset='TEAM_NAME', keep='first'), how='left', left_on='Team', right_on='TEAM_NAME')
    df_adjusted.drop(columns=['TEAM_NAME'], inplace=True)
    df_adjusted.rename(columns={'TEAM_ID': 'Team_Id'}, inplace=True)

# drop games from games_df that don't include teams in df_adjusted
games_df = games_df[games_df['TEAM_ID'].isin(df_adjusted['Team_Id'].unique())]
games_df.drop_duplicates(subset=['GAME_ID'], inplace=True) # remove duplicate games
games_df.reset_index(drop=True, inplace=True)

# %%
# from io import StringIO
# from bs4 import BeautifulSoup
# import pandas as pd

import requests
from IPython.display import clear_output

url_format = "https://cdn.nba.com/static/json/liveData/boxscore/boxscore_{game_id}.json"
games_played_df_list = []
for i, row in games_df.iterrows():
    vs_str = row.MATCHUP.lower().replace(' ', '-').replace('.', '')
    game_id = row.GAME_ID
    url = url_format.format(game_id=game_id)

    response = requests.get(url)
    data = response.json()

    for team_type in ['home', 'away']:
        team = data['game'][f'{team_type}Team']
        player_data = [
            {
                "personId": p["personId"],
                "played": int(p.get("played", 0)),  # cast to int just in case
                "name": p["name"],
                "teamId": team['teamId'],
                'teamAbbr': team['teamTricode'],
            }
            for p in team['players']
        ]
        player_df = pd.DataFrame(player_data)
        games_played_df_list.append(player_df)
    
    clear_output(wait=True)
    print(f"Processed game {i+1}/{len(games_df)}: {game_id}")

games_played_df = pd.concat(games_played_df_list)
        # if team['teamId'] == row.TEAM_ID:
        #     for player in team['players']:
        #         if player['name'] in as_players:
        #             if int(player['played']) == 0:
        #                 # missed games
        #                 df_adjusted.loc[df_adjusted.Team_Id == team['teamId'], 'missed_games'] += 1
# Out:
# Processed game 894/894: 0022400066

# %%
# storing in df and dumping intermediate data to files for reusability

# read pkl for games_played_df if games_played_df_list does not exist
if 'games_played_df_list' not in locals():
    try:
        with open(f'data/games_played_{max_year-1}-{str(max_year)[-2:]}.pkl', "rb") as f:
            games_played_df = pickle.load(f)
    except FileNotFoundError:
        games_played_df = pd.DataFrame()

else:
    games_played_df = pd.concat(games_played_df_list)
    fbase = f'games_played_{max_year-1}-{str(max_year)[-2:]}'
    if not os.path.exists(f'data/{fbase}.csv'):
        games_played_df.to_csv(f'data/{fbase}.csv', index=False)
    if not os.path.exists(f'data/{fbase}.pkl'):
        with open(f'data/{fbase}.pkl', "wb") as f:
            pickle.dump(games_played_df, f)

# %%
# counting missed games by all stars for each team

df_adjusted['missed_games'] = 0
df_adjusted['played_games'] = 0
for i, player_data in games_played_df.iterrows():
    logic = (player_data['teamId'] in df_adjusted.Team_Id.values) & \
            (player_data['name'] in as_players)
    if not logic:
        continue
    if (int(player_data['played']) == 0):
    # if logic:
        df_adjusted.loc[df_adjusted.Team_Id == player_data['teamId'], 'missed_games'] += 1
    else:
        df_adjusted.loc[df_adjusted.Team_Id == player_data['teamId'], 'played_games'] += 1

df_adjusted['all_star_percent_played'] = df_adjusted['played_games'] / (df_adjusted['played_games'] + df_adjusted['missed_games'])
df_adjusted['all_star_percent_played'] = df_adjusted['all_star_percent_played'].fillna(1)

# %%
import math
# subtract 0.5 lottery balls per missed game by all star player
df_adjusted['balls_lottery_luck_adjusted'] *= df_adjusted['all_star_percent_played']
# df_adjusted['balls_lottery_luck_adjusted'] -= df_adjusted['missed_games'].apply(lambda x: math.ceil(x * 0.5))
df_adjusted['#1 Ovr Adjusted'] = (df_adjusted['balls_lottery_luck_adjusted'] / df_adjusted['balls_lottery_luck_adjusted'].sum() * 100).round(2).astype(str) + '%'

# %%
df_adjusted
# Out:
#    Pick                    Team Record  Win%    GB  Streak  L10  Top 4 #1 Ovr  \
# 0    54               Utah Jazz  17-65  .207    --  Lost 2  1-9  52.1%  14.0%
# 1    41       Charlotte Hornets  19-63  .232   2.0  Lost 7  1-9  52.1%  14.0%
# 2    64      Washington Wizards  18-64  .220   1.0   Won 1  2-8  52.1%  14.0%
# 3    73    New Orleans Pelicans  21-61  .256   4.0  Lost 7  2-8  48.1%  12.5%
# 4    32      Philadelphia 76ers  24-58  .293   7.0  Lost 2  1-9  42.1%  10.5%
# 5    92         Toronto Raptors  30-52  .366  13.0  Lost 2  5-5  31.9%   7.5%
# 6   111  Portland Trail Blazers  36-46  .439  19.0   Won 1  4-6  16.9%   3.7%
# 7    26       San Antonio Spurs  34-48  .415  17.0   Won 1  3-7  26.3%   6.0%
# 8   101            Phoenix Suns  36-46  .439  19.0  Lost 1  1-9  17.3%   3.8%
# 9    82           Brooklyn Nets  26-56  .317   9.0  Lost 3  3-7  37.2%   9.0%
# 10  110        Dallas Mavericks  39-43  .476  22.0  Lost 1  4-6   8.5%   1.8%
# 11   12           Chicago Bulls  39-43  .476  22.0   Won 3  7-3   8.0%   1.7%
# 12   13        Sacramento Kings  40-42  .488  23.0   Won 1  5-5   3.8%   0.8%
# 13   14           Atlanta Hawks  40-42  .488  23.0   Won 3  5-5   3.4%   0.7%
#
#     Pick Change_2020  ...  Pick Change_2022  Pick Change_2023  \
# 0                NaN  ...               NaN               0.0
# 1                5.0  ...               0.0               2.0
# 2                0.0  ...               0.0               0.0
# 3                0.0  ...               NaN               0.0
# 4                NaN  ...               NaN               NaN
# 5                NaN  ...               NaN               0.0
# 6                NaN  ...              -1.0               2.0
# 7                0.0  ...               0.0               2.0
# 8                0.0  ...               NaN               NaN
# 9                NaN  ...               NaN               NaN
# 10               NaN  ...               NaN               0.0
# 11               3.0  ...               NaN               0.0
# 12               0.0  ...               3.0               NaN
# 13              -2.0  ...               NaN               NaN
#
#     Pick Change_2024  start_balls  balls_lottery_luck_adjusted  \
# 0               -2.0        140.0                    91.707317
# 1               -3.0        140.0                    85.975610
# 2                0.0        140.0                    61.250000
# 3                NaN        125.0                    46.493902
# 4                NaN        105.0                    47.804878
# 5               -2.0         75.0                    69.359756
# 6               -3.0         37.0                    60.333333
# 7                1.0         60.0                    33.559322
# 8                NaN         38.0                    31.743902
# 9                6.0         90.0                    30.000000
# 10               NaN         18.0                     9.234783
# 11               0.0         17.0                     9.240000
# 12               0.0          8.0                    -1.821138
# 13               9.0          7.0                   -73.219512
#
#     #1 Ovr Adjusted missed_games  played_games     Team_Id  \
# 0            18.28%           35            47  1610612762
# 1            17.14%           35            47  1610612766
# 2            12.21%           18            14  1610612764
# 3             9.27%          103            61  1610612740
# 4             9.53%          134           112  1610612755
# 5            13.83%           17            65  1610612761
# 6            12.03%            0             0  1610612757
# 7             6.69%           19            99  1610612759
# 8             6.33%           27           137  1610612756
# 9             5.98%            0             0  1610612751
# 10            1.84%           56            59  1610612742
# 11            1.84%            8            42  1610612741
# 12           -0.36%           22           224  1610612758
# 13           -14.6%            6            76  1610612737
#
#     all_star_percent_played
# 0                  0.573171
# 1                  0.573171
# 2                  0.437500
# 3                  0.371951
# 4                  0.455285
# 5                  0.792683
# 6                  1.000000
# 7                  0.838983
# 8                  0.835366
# 9                  1.000000
# 10                 0.513043
# 11                 0.840000
# 12                 0.910569
# 13                 0.926829
#
# [14 rows x 21 columns]

# %%
test = df_adjusted[['Team','balls_lottery_luck_adjusted','#1 Ovr Adjusted']].copy()

# %% [markdown]
# ## Top 3 Pick Recency Penalty

# %%
# 1/4 scaled by years since for recent number 1 pick
# 1/2 scaled by years since for recent number 2 pick
# 3/4 scaled by years since for recent number 3 pick
test = df_adjusted.copy()
for year, draft_dict in draft_lottery_history.items():
    pick_series = draft_dict[['Team','Pick']]

    for pick, adjustment in enumerate([0.75, 0.5, 0.25]):
        team_name = pick_series.iloc[pick]['Team']
        # team_name_mapped = tankathon_bballgm_team_mapper.get(team_name, team_name)
        if test[test['Team'] == team_name].empty:
            continue

        test.loc[test['Team'] == team_name, 'balls_lottery_luck_adjusted'] *= (1 - (adjustment / (int(max_year) - int(year))))

    # round up balls_lottery_luck_adjusted
    test.loc[:,'balls_lottery_luck_adjusted'] = test['balls_lottery_luck_adjusted'].apply(lambda x: math.ceil(x))

test['#1 Ovr Adjusted'] = (test['balls_lottery_luck_adjusted'] / test['balls_lottery_luck_adjusted'].sum() * 100).round(2).astype(str) + '%'

# %%
test
# Out:
#    Pick                    Team Record  Win%    GB  Streak  L10  Top 4 #1 Ovr  \
# 0    54               Utah Jazz  17-65  .207    --  Lost 2  1-9  52.1%  14.0%
# 1    41       Charlotte Hornets  19-63  .232   2.0  Lost 7  1-9  52.1%  14.0%
# 2    64      Washington Wizards  18-64  .220   1.0   Won 1  2-8  52.1%  14.0%
# 3    73    New Orleans Pelicans  21-61  .256   4.0  Lost 7  2-8  48.1%  12.5%
# 4    32      Philadelphia 76ers  24-58  .293   7.0  Lost 2  1-9  42.1%  10.5%
# 5    92         Toronto Raptors  30-52  .366  13.0  Lost 2  5-5  31.9%   7.5%
# 6   111  Portland Trail Blazers  36-46  .439  19.0   Won 1  4-6  16.9%   3.7%
# 7    26       San Antonio Spurs  34-48  .415  17.0   Won 1  3-7  26.3%   6.0%
# 8   101            Phoenix Suns  36-46  .439  19.0  Lost 1  1-9  17.3%   3.8%
# 9    82           Brooklyn Nets  26-56  .317   9.0  Lost 3  3-7  37.2%   9.0%
# 10  110        Dallas Mavericks  39-43  .476  22.0  Lost 1  4-6   8.5%   1.8%
# 11   12           Chicago Bulls  39-43  .476  22.0   Won 3  7-3   8.0%   1.7%
# 12   13        Sacramento Kings  40-42  .488  23.0   Won 1  5-5   3.8%   0.8%
# 13   14           Atlanta Hawks  40-42  .488  23.0   Won 3  5-5   3.4%   0.7%
#
#     Pick Change_2020  ...  Pick Change_2022  Pick Change_2023  \
# 0                NaN  ...               NaN               0.0
# 1                5.0  ...               0.0               2.0
# 2                0.0  ...               0.0               0.0
# 3                0.0  ...               NaN               0.0
# 4                NaN  ...               NaN               NaN
# 5                NaN  ...               NaN               0.0
# 6                NaN  ...              -1.0               2.0
# 7                0.0  ...               0.0               2.0
# 8                0.0  ...               NaN               NaN
# 9                NaN  ...               NaN               NaN
# 10               NaN  ...               NaN               0.0
# 11               3.0  ...               NaN               0.0
# 12               0.0  ...               3.0               NaN
# 13              -2.0  ...               NaN               NaN
#
#     Pick Change_2024  start_balls  balls_lottery_luck_adjusted  \
# 0               -2.0        140.0                         92.0
# 1               -3.0        140.0                         62.0
# 2                0.0        140.0                         31.0
# 3                NaN        125.0                         47.0
# 4                NaN        105.0                         48.0
# 5               -2.0         75.0                         70.0
# 6               -3.0         37.0                         54.0
# 7                1.0         60.0                         22.0
# 8                NaN         38.0                         32.0
# 9                6.0         90.0                         23.0
# 10               NaN         18.0                         10.0
# 11               0.0         17.0                         10.0
# 12               0.0          8.0                         -1.0
# 13               9.0          7.0                        -18.0
#
#     #1 Ovr Adjusted missed_games  played_games     Team_Id  \
# 0            19.09%           35            47  1610612762
# 1            12.86%           35            47  1610612766
# 2             6.43%           18            14  1610612764
# 3             9.75%          103            61  1610612740
# 4             9.96%          134           112  1610612755
# 5            14.52%           17            65  1610612761
# 6             11.2%            0             0  1610612757
# 7             4.56%           19            99  1610612759
# 8             6.64%           27           137  1610612756
# 9             4.77%            0             0  1610612751
# 10            2.07%           56            59  1610612742
# 11            2.07%            8            42  1610612741
# 12           -0.21%           22           224  1610612758
# 13           -3.73%            6            76  1610612737
#
#     all_star_percent_played
# 0                  0.573171
# 1                  0.573171
# 2                  0.437500
# 3                  0.371951
# 4                  0.455285
# 5                  0.792683
# 6                  1.000000
# 7                  0.838983
# 8                  0.835366
# 9                  1.000000
# 10                 0.513043
# 11                 0.840000
# 12                 0.910569
# 13                 0.926829
#
# [14 rows x 21 columns]

# %%
test.loc[test['Team'] == team_name, 'balls_lottery_luck_adjusted']
# Out:
# 9    22.5
# Name: balls_lottery_luck_adjusted, dtype: float64

# %%
max_year
# Out:
# 2025

# %%
(1 - (adjustment / (int(max_year) - int(year))))
# Out:
# 0.75

# %%
df_display = test[['Team','#1 Ovr Adjusted', 'balls_lottery_luck_adjusted']]
df_display
# Out:
#                       Team #1 Ovr Adjusted  balls_lottery_luck_adjusted
# 0                Utah Jazz          19.09%                         92.0
# 1        Charlotte Hornets          12.86%                         62.0
# 2       Washington Wizards           6.43%                         31.0
# 3     New Orleans Pelicans           9.75%                         47.0
# 4       Philadelphia 76ers           9.96%                         48.0
# 5          Toronto Raptors          14.52%                         70.0
# 6   Portland Trail Blazers           11.2%                         54.0
# 7        San Antonio Spurs           4.56%                         22.0
# 8             Phoenix Suns           6.64%                         32.0
# 9            Brooklyn Nets           4.77%                         23.0
# 10        Dallas Mavericks           2.07%                         10.0
# 11           Chicago Bulls           2.07%                         10.0
# 12        Sacramento Kings          -0.21%                         -1.0
# 13           Atlanta Hawks          -3.73%                        -18.0

# %%
draft_lottery_history
# Out:
# {2020:    Pick                    Team Record    Odds Chances Pre-Lottery Position  \
#  0     1  Minnesota Timberwolves  19-45  14.00%     140                  3rd
#  1     2   Golden State Warriors  15-50  14.00%     140                  1st
#  2     3       Charlotte Hornets  23-42   6.00%      60                  8th
#  3     4           Chicago Bulls  22-43   7.50%      75                  7th
#  4     5     Cleveland Cavaliers  19-46  14.00%     140                  2nd
#  5     6           Atlanta Hawks  20-47  12.50%     125                  4th
#  6     7         Detroit Pistons  20-46  10.50%     105                  5th
#  7     8         New York Knicks  21-45   9.00%      90                  6th
#  8     9      Washington Wizards  25-47   4.50%      45                  9th
#  9    10            Phoenix Suns  34-39   3.00%      30                 10th
#  10   11       San Antonio Spurs  32-39   2.00%      20                 11th
#  11   12        Sacramento Kings  31-41   1.30%      13                 12th
#  12   13    New Orleans Pelicans  30-42   1.20%      12                 13th
#  13   14       Memphis Grizzlies  34-39   0.50%       5                 14th
#
#      Pick Change       Player Taken              Draft Team
#  0             2    Anthony Edwards  Minnesota Timberwolves
#  1            -1      James Wiseman   Golden State Warriors
#  2             5        LaMelo Ball       Charlotte Hornets
#  3             3   Patrick Williams           Chicago Bulls
#  4            -3        Isaac Okoro     Cleveland Cavaliers
#  5            -2     Onyeka Okongwu           Atlanta Hawks
#  6            -2      Killian Hayes         Detroit Pistons
#  7            -2         Obi Toppin         New York Knicks
#  8             0        Deni Avdija      Washington Wizards
#  9             0        Jalen Smith            Phoenix Suns
#  10            0      Devin Vassell       San Antonio Spurs
#  11            0  Tyrese Haliburton        Sacramento Kings
#  12            0    Kira Lewis, Jr.    New Orleans Pelicans
#  13            0      Aaron Nesmith          Boston Celtics  ,
#  2021:    Pick                   Team Record    Odds Chances Pre-Lottery Position  \
#  0     1        Detroit Pistons  20-52  14.00%     140                  2nd
#  1     2        Houston Rockets  17-55  14.00%     140                  1st
#  2     3    Cleveland Cavaliers  22-50  11.50%     115                  5th
#  3     4        Toronto Raptors  27-45   7.50%      75                  7th
#  4     5          Orlando Magic  21-51  14.00%     140                  3rd
#  5     6  Oklahoma City Thunder  22-50  11.50%     115                  4th
#  6     7  Golden State Warriors  23-49   9.00%      90                  6th
#  7     8          Chicago Bulls  31-41   4.50%      45                  8th
#  8     9       Sacramento Kings  31-41   4.50%      45                  9th
#  9    10   New Orleans Pelicans  31-41   4.50%      45                 10th
#  10   11      Charlotte Hornets  33-39   1.80%      18                 11th
#  11   12      San Antonio Spurs  33-39   1.70%      17                 12th
#  12   13         Indiana Pacers  34-38   1.00%      10                 13th
#  13   14  Golden State Warriors  39-33   0.50%       5                 14th
#
#      Pick Change      Player Taken             Draft Team
#  0             1   Cade Cunningham        Detroit Pistons
#  1            -1       Jalen Green        Houston Rockets
#  2             2       Evan Mobley    Cleveland Cavaliers
#  3             3    Scottie Barnes        Toronto Raptors
#  4            -2       Jalen Suggs          Orlando Magic
#  5            -2       Josh Giddey  Oklahoma City Thunder
#  6            -1  Jonathan Kuminga  Golden State Warriors
#  7             0      Franz Wagner          Orlando Magic
#  8             0   Davion Mitchell       Sacramento Kings
#  9             0   Ziaire Williams   New Orleans Pelicans
#  10            0   James Bouknight      Charlotte Hornets
#  11            0      Joshua Primo      San Antonio Spurs
#  12            0      Chris Duarte         Indiana Pacers
#  13            0       Moses Moody  Golden State Warriors  ,
#  2022:    Pick                    Team Record    Odds Chances Pre-Lottery Position  \
#  0     1           Orlando Magic  22-60  14.00%     140                  2nd
#  1     2   Oklahoma City Thunder  24-58  12.50%     125                  4th
#  2     3         Houston Rockets  20-62  14.00%     140                  1st
#  3     4        Sacramento Kings  30-52   7.50%      75                  7th
#  4     5         Detroit Pistons  23-59  14.00%     140                  3rd
#  5     6          Indiana Pacers  25-57  10.50%     105                  5th
#  6     7  Portland Trail Blazers  27-55   9.00%      90                  6th
#  7     8      Los Angeles Lakers  33-49   6.00%      60                  8th
#  8     9       San Antonio Spurs  34-48   4.50%      45                  9th
#  9    10      Washington Wizards  35-47   3.00%      30                 10th
#  10   11         New York Knicks  37-45   2.00%      20                 11th
#  11   12    Los Angeles Clippers  42-40   1.50%      15                 12th
#  12   13       Charlotte Hornets  43-39   1.00%      10                 13th
#  13   14     Cleveland Cavaliers  44-38   0.50%       5                 14th
#
#      Pick Change        Player Taken              Draft Team
#  0             1      Paolo Banchero           Orlando Magic
#  1             2       Chet Holmgren   Oklahoma City Thunder
#  2            -2   Jabari Smith, Jr.         Houston Rockets
#  3             3       Keegan Murray        Sacramento Kings
#  4            -2          Jaden Ivey         Detroit Pistons
#  5            -1  Bennedict Mathurin          Indiana Pacers
#  6            -1      Shaedon Sharpe  Portland Trail Blazers
#  7             0       Dyson Daniels    New Orleans Pelicans
#  8             0       Jeremy Sochan       San Antonio Spurs
#  9             0        Johnny Davis      Washington Wizards
#  10            0       Ousmane Dieng         New York Knicks
#  11            0      Jalen Williams   Oklahoma City Thunder
#  12            0         Jalen Duren       Charlotte Hornets
#  13            0        Ochai Agbaji     Cleveland Cavaliers  ,
#  2023:    Pick                    Team Record    Odds Chances Pre-Lottery Position  \
#  0     1       San Antonio Spurs  22-60  14.00%     140                  3rd
#  1     2       Charlotte Hornets  27-55  12.50%     125                  4th
#  2     3  Portland Trail Blazers  33-49  10.50%     105                  5th
#  3     4         Houston Rockets  22-60  14.00%     140                  2nd
#  4     5         Detroit Pistons  17-65  14.00%     140                  1st
#  5     6           Orlando Magic  34-48   9.00%      90                  6th
#  6     7          Indiana Pacers  35-47   6.80%      68                  7th
#  7     8      Washington Wizards  35-47   6.70%      67                  8th
#  8     9               Utah Jazz  37-45   4.50%      45                  9th
#  9    10        Dallas Mavericks  38-44   3.00%      30                 10th
#  10   11           Chicago Bulls  40-42   1.80%      18                 11th
#  11   12   Oklahoma City Thunder  40-42   1.70%      17                 12th
#  12   13         Toronto Raptors  41-41   1.00%      10                 13th
#  13   14    New Orleans Pelicans  42-40   0.50%       5                 14th
#
#      Pick Change       Player Taken              Draft Team
#  0             2  Victor Wembanyama       San Antonio Spurs
#  1             2     Brandon Miller       Charlotte Hornets
#  2             2    Scoot Henderson  Portland Trail Blazers
#  3            -2      Amen Thompson         Houston Rockets
#  4            -4     Ausar Thompson         Detroit Pistons
#  5             0      Anthony Black           Orlando Magic
#  6             0    Bilal Coulibaly          Indiana Pacers
#  7             0      Jarace Walker      Washington Wizards
#  8             0   Taylor Hendricks               Utah Jazz
#  9             0      Cason Wallace        Dallas Mavericks
#  10            0        Jett Howard           Orlando Magic
#  11            0   Dereck Lively II   Oklahoma City Thunder
#  12            0        Gradey Dick         Toronto Raptors
#  13            0     Jordan Hawkins    New Orleans Pelicans  ,
#  2024:    Pick                    Team Record    Odds Chances Pre-Lottery Position  \
#  0     1           Atlanta Hawks  36-46   3.00%      30                 10th
#  1     2      Washington Wizards  15-67  14.00%     140                  2nd
#  2     3           Brooklyn Nets  32-50   4.50%      45                  9th
#  3     4       San Antonio Spurs  22-60  10.50%     105                  5th
#  4     5         Detroit Pistons  14-68  14.00%     140                  1st
#  5     6       Charlotte Hornets  21-61  13.30%     133                  3rd
#  6     7  Portland Trail Blazers  21-61  13.20%     132                  4th
#  7     8         Toronto Raptors  25-57   9.00%      90                  6th
#  8     9       Memphis Grizzlies  27-55   7.50%      75                  7th
#  9    10               Utah Jazz  31-51   6.00%      60                  8th
#  10   11           Chicago Bulls  39-43   2.00%      20                 11th
#  11   12         Houston Rockets  41-41   1.50%      15                 12th
#  12   13        Sacramento Kings  46-36   0.80%       8                 13th
#  13   14   Golden State Warriors  46-36   0.70%       7                 14th
#
#      Pick Change        Player Taken              Draft Team
#  0             9  Zaccharie Risacher           Atlanta Hawks
#  1             0           Alex Sarr      Washington Wizards
#  2             6       Reed Sheppard         Houston Rockets
#  3             1      Stephon Castle       San Antonio Spurs
#  4            -4         Ron Holland         Detroit Pistons
#  5            -3      Tidjane Salaun       Charlotte Hornets
#  6            -3     Donovan Clingan  Portland Trail Blazers
#  7            -2      Rob Dillingham       San Antonio Spurs
#  8            -2           Zach Edey       Memphis Grizzlies
#  9            -2       Cody Williams               Utah Jazz
#  10            0       Matas Buzelis           Chicago Bulls
#  11            0        Nikola Topic   Oklahoma City Thunder
#  12            0        Devin Carter        Sacramento Kings
#  13            0      Bub Carrington  Portland Trail Blazers  }
