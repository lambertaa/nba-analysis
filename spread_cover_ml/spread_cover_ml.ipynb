# %%
import os
import sys
import pandas as pd

# for local imports
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

# %%
from data_retrieval.betting.historical_spreads import SpreadCoverageRetriever

# %%
retriever = SpreadCoverageRetriever()

# %%
pd.DataFrame(retriever.get_games_by_date("2023-11-14"))
# Out:
#          date away_team home_team  ...  cover_team  cover_margin total_score
# 0  2023-11-14       MIA       CHA  ...         MIA             6         216
# 1  2023-11-14       IND       PHI  ...         IND             6         258
# 2  2023-11-14       ATL       DET  ...         ATL             6         246
# 3  2023-11-14        SA       OKC  ...         OKC           -36         210
# 4  2023-11-14       ORL        BK  ...          BK           -20         228
# 5  2023-11-14       DAL        NO  ...          NO           -21         241
# 6  2023-11-14       POR       UTA  ...         UTA           -16         214
# 7  2023-11-14       LAC       DEN  ...         DEN            -3         219
# 8  2023-11-14       MIN        GS  ...         MIN             3         205
# 9  2023-11-14       MEM       LAL  ...         LAL           -27         241
#
# [10 rows x 13 columns]
